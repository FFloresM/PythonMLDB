# %%
import pandas as pd

# %%
datos = pd.read_excel("Estadistica.xlsm", sheet_name = 8, engine='openpyxl')
# Out:
# /home/francisco/.local/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:308: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
datos
# Out:
#       JUEZ SALA         RIT         F. AUDIENCIA ADM. SALA ASISTENTES  \
# 0     CARO    1  F-745-2016  2017-01-03 00:00:00       MVL        NIA
# 1     CARO    1  F-724-2016  2017-01-03 00:00:00       MVL        NIA
# 2     CARO    1  Z-194-2016  2017-01-03 00:00:00       MVL        NaN
# 3     CARO    1  Z-907-2015  2017-01-03 00:00:00       MVL        NaN
# 4     CARO    1  X-150-2015  2017-01-03 00:00:00       MVL        NaN
# ...    ...  ...         ...                  ...       ...        ...
# 5344   NaN  NaN         NaN                  NaN       NaN        NaN
# 5345   NaN  NaN         NaN                  NaN       NaN        NaN
# 5346   NaN  NaN         NaN                  NaN       NaN        NaN
# 5347   NaN  NaN         NaN                  NaN       NaN        NaN
# 5348   NaN  NaN         NaN                  NaN       NaN        NaN
#
#      A. PUBLICO              TIPO DE AUDIENCIA  \
# 0          OF.5                A. PREPARATORIA
# ...

# %%
datos.dropna(how = "all")
# Out:
#          JUEZ SALA         RIT         F. AUDIENCIA ADM. SALA ASISTENTES  \
# 0        CARO    1  F-745-2016  2017-01-03 00:00:00       MVL        NIA
# 1        CARO    1  F-724-2016  2017-01-03 00:00:00       MVL        NIA
# 2        CARO    1  Z-194-2016  2017-01-03 00:00:00       MVL        NaN
# 3        CARO    1  Z-907-2015  2017-01-03 00:00:00       MVL        NaN
# 4        CARO    1  X-150-2015  2017-01-03 00:00:00       MVL        NaN
# ...       ...  ...         ...                  ...       ...        ...
# 5317  CANOVAS  NaN  C-996-2020  2021-02-12 00:00:00       AME          0
# 5318  CANOVAS  NaN  C-335-2020  2021-02-12 00:00:00       AME          0
# 5319  CANOVAS  NaN  F-583-2020  2021-02-12 00:00:00       AME          0
# 5320  CANOVAS  NaN  C-127-2021  2021-02-16 00:00:00       AME          2
# 5321   VARGAS  NaN    C-3-2021  2021-02-16 00:00:00       AME          0
#
#      A. PUBLICO              TIPO DE AUDIENCIA  \
# ...

# %%
datos.columns
# Out:
# Index(['JUEZ', 'SALA', 'RIT', 'F. AUDIENCIA', 'ADM. SALA', 'ASISTENTES',
#        'A. PUBLICO', 'TIPO DE AUDIENCIA', 'MATERIA', 'REALIZACION', 'MOTIVO',
#        'AMBAS PARTES RENUNCIAN PL', 'FECHA N. AUD', 'Bloques', 'Fecha Firma',
#        'CAUSA X?', 'RIT.1', 'FECHA 1RA RESOLUCION', 'OBSERVACIONES',
#        'Unnamed: 19'],
#       dtype='object')

# %%
datos["F. AUDIENCIA"]
# Out:
# 0       2017-01-03 00:00:00
# 1       2017-01-03 00:00:00
# 2       2017-01-03 00:00:00
# 3       2017-01-03 00:00:00
# 4       2017-01-03 00:00:00
#                ...
# 5344                   None
# 5345                   None
# 5346                   None
# 5347                   None
# 5348                   None
# Name: F. AUDIENCIA, Length: 5349, dtype: object

# %%
datos["F. AUDIENCIA"].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-f5f7859e66f5> in <module>
# ----> 1 datos["F. AUDIENCIA"].to_datetime()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_datetime'
